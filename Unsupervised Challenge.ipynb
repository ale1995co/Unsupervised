# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.decomposition import PCA
from sklearn import datasets
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings("ignore")

# %%
avocado = pd.read_csv('avocado.csv')

# %%
avocado.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
# Unnamed: 0      18249 non-null int64
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
features = ['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
       '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
       'year', 'region' ]

# %%
def type(x):
    if x['type'] == 'conventional':
        return 0
    
    elif x['type'] == 'organic':
        return 1
    
    else: 
        return 2
    

avocado['type'] = avocado.apply(type, axis = 1)

# %%
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# 0   48.16     8696.87     8603.62       93.25          0.0     0  2015  Albany
# 1   58.33     9505.56     9408.07       97.49          0.0     0  2015  Albany
# 2  130.50     8145.35     8042.21      103.14          0.0     0  2015  Albany
# 3   72.58     5811.16     5677.40      133.76          0.0     0  2015  Albany
# 4   75.78     6183.95     5986.26      197.69          0.0     0  2015  Albany

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
# Unnamed: 0      18249 non-null int64
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null int64
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
avocado.drop(['region', 'Unnamed: 0'],axis = 1, inplace = True)

# %%
avocado.Date = pd.to_datetime(avocado.Date).dt.strftime('%Y')

# %%
avocado.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0  2015          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1  2015          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2  2015          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3  2015          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4  2015          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year
# 0     8603.62       93.25          0.0     0  2015
# 1     9408.07       97.49          0.0     0  2015
# 2     8042.21      103.14          0.0     0  2015
# 3     5677.40      133.76          0.0     0  2015
# 4     5986.26      197.69          0.0     0  2015

# %%
avocado.isnull().sum()*100/avocado.isnull().count()
# Out:
# Date            0.0
# AveragePrice    0.0
# Total Volume    0.0
# 4046            0.0
# 4225            0.0
# 4770            0.0
# Total Bags      0.0
# Small Bags      0.0
# Large Bags      0.0
# XLarge Bags     0.0
# type            0.0
# year            0.0
# dtype: float64

# %%
def year(x):
    if x['year'] == '2015':
        return 0
    
    elif x['year'] == '2016':
        return 1
    
    elif x['year'] == '2017':
        return 2
    
    elif x['year'] == '2018':
        return 3
    
    else: 
        return 4
    

avocado['year'] = avocado.apply(type, axis = 1)

# %%
# Preprocessing the dataset

# Define the features and the outcome
y = avocado['year']
X = avocado.drop('year', axis = 1)


# Standardizing the features

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Defining the k-means
kmeans_cluster = KMeans(n_clusters = 4, random_state = 12)

# Fit model
kmeans_cluster.fit(X_std)
y_pred = kmeans_cluster.predict(X_std)

# %%
pca = PCA(n_components=2).fit_transform(X_std)

plt.figure(figsize=(10,5))
colours = 'rbg'
for i in range(pca.shape[0]):
    plt.text(pca[i, 0], pca[i, 1], str(y_pred[i]),
             color=colours[y[i]],
             fontdict={'weight': 'bold', 'size': 50}
        )

plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %%
from sklearn import datasets, metrics

metrics.adjusted_rand_score(y, y_pred)
# Out:
# 0.0

# %%
# Defining the mini-batch k-means
minikmeans_cluster = MiniBatchKMeans(
    init='random',
    n_clusters=3,
    batch_size=50)

# Fit model
# %timeit minikmeans_cluster.fit(X_std)
minikmeans_cluster = minikmeans_cluster.predict(X_std)

plt.figure(figsize=(10,5))
colours = 'rbg'
for i in range(pca.shape[0]):
    plt.text(pca[i, 0], pca[i, 1], str(minikmeans_cluster[i]),
             color=colours[y[i]],
             fontdict={'weight': 'bold', 'size': 50}
        )

plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()
# Out:
# 121 ms ± 28.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
avocado.type.value_counts()
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %%
# Defining the k-means
kmeans_cluster = KMeans(n_clusters = 4, random_state = 12)

# Fit model
kmeans_cluster.fit(X_std)
y_pred = kmeans_cluster.predict(X_std)

metrics.adjusted_rand_score(y, y_pred)
# Out:
# 0.0

# %%
# Defining the k-means
kmeans_cluster = KMeans(n_clusters = 3, random_state = 12)

# Fit model
kmeans_cluster.fit(X_std)
y_pred = kmeans_cluster.predict(X_std)

metrics.adjusted_rand_score(y, y_pred)
# Out:
# 0.0
